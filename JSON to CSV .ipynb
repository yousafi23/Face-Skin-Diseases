# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import json

# %%
json_file = '/content/drive/MyDrive/Colab_Skin_Disease/11 july 2023 (2).json'

# %%
# Load the JSON data
with open(json_file, 'r') as file:
    data = json.load(file)

# Extract the regions from the JSON data
regions = []
for filename, file_data in data['_via_img_metadata'].items():
    if 'filename' and 'regions' in file_data:
        for region in file_data['regions']:
            if region is not None:
                region_attributes = region.get('region_attributes', {})
                if region_attributes is None:
                    region_attributes = {}

                shape_attributes = region.get('shape_attributes', {})
                if shape_attributes is not None:
                  region_dict = {
                            'filename':file_data['filename'],
                            'region_shape_attributes':shape_attributes,
                            'region_attributes': region_attributes
                        }
                  regions.append(region_dict)
    # break

# Create the DataFrame
df = pd.DataFrame(regions)

# Print the DataFrame
df
# Out:
#      filename                            region_shape_attributes  \
# 0     1a.jpeg  {'name': 'circle', 'cx': 441, 'cy': 631, 'r': ...
# 1     1a.jpeg  {'name': 'circle', 'cx': 455, 'cy': 632, 'r': ...
# 2     1a.jpeg  {'name': 'circle', 'cx': 408, 'cy': 662, 'r': 10}
# 3     b1.jpeg  {'name': 'circle', 'cx': 335, 'cy': 406, 'r': 12}
# 4     b1.jpeg   {'name': 'circle', 'cx': 358, 'cy': 285, 'r': 6}
# ...       ...                                                ...
# 1773   z2.JPG  {'name': 'circle', 'cx': 1410, 'cy': 2363, 'r'...
# 1774   z2.JPG  {'name': 'circle', 'cx': 1487, 'cy': 2032, 'r'...
# 1775   z2.JPG  {'name': 'circle', 'cx': 1657, 'cy': 2494, 'r'...
# 1776   z3.JPG  {'name': 'circle', 'cx': 1472, 'cy': 1785, 'r'...
# 1777   z3.JPG  {'name': 'circle', 'cx': 1581, 'cy': 2384, 'r'...
#
#                                       region_attributes
# 0                                  {'Acne scars ': '1'}
# 1     {'Wrinkels': '', 'Melasma': '', 'Frackels': ''...
# 2     {'Wrinkels': '', 'Melasma': '', 'Frackels': ''...
# 3     {'Wrinkels': '', 'Melasma': '', 'Frackels': ''...
# 4     {'Wrinkels': '', 'Melasma': '', 'Frackels': '1...
# ...                                                 ...
# 1773  {'Wrinkels': '', 'Melasma': '', 'Acne scars ':...
# 1774  {'Wrinkels': '', 'Melasma': '', 'Acne scars ':...
# 1775  {'Wrinkels': '', 'Melasma': '', 'Acne scars ':...
# 1776  {'Wrinkels': '', 'Melasma': '', 'Acne scars ':...
# 1777  {'Wrinkels': '', 'Melasma': '1', 'Acne scars '...
#
# [1778 rows x 3 columns]

# %%
df.to_csv('/content/drive/MyDrive/Colab_Skin_Disease/json_to_csv.csv',index=False)
